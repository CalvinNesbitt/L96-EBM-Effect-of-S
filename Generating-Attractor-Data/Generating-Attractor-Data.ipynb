# %%
from main import generate_attractors
import numpy as np

# %%
# S Values we're interested in
sb_S_values = [6, 7, 7.73, 7.8, 7.9] + list(range(8, 16)) + [15.1, 15.2, 15.28]
sb_W_values = [7.73, 7.8, 7.9] + list(range(8, 16)) + [15.1, 15.2, 15.28, 16, 17]

# %%
generate_attractors(sb_S_values, ['sb'])
generate_attractors(sb_W_values, ['w'])
# Out:
# **Generating sb attractor data for S = 1.000.**
#
#
# Made directory at /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_1_000/SB-State/
# Spinning Up
# Observations written to /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_1_000/SB-State//1.nc. Erasing personal log.
#
# **Generating w attractor data for S = 50.000.**
#
#
# Made directory at /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_50_000/W-State/
# Spinning Up
# Observations written to /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_50_000/W-State//1.nc. Erasing personal log.
