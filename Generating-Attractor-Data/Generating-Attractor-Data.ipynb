# %%
from main import generate_attractors
import numpy as np

# %%
# S Values we're interested in
sb_S_values = list(np.append(np.arange(7, 16), np.linspace(15.1, 15.5, 5)))
sb_W_values = list(np.append(np.linspace(7.5, 7.9, 5), np.arange(8, 15)))

# %%
generate_attractors(sb_S_values, ['sb'])
generate_attractors(sb_S_values, ['w'])
# Out:
# **Generating sb attractor data for S = 7.000.**
#
#
# Made directory at /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_7_000/SB-State/
# Spinning Up
# Observations written to /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_7_000/SB-State//1.nc. Erasing personal log.
#
# **Generating sb attractor data for S = 8.000.**
#
#
# Made directory at /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_8_000/SB-State/
# Spinning Up
# Observations written to /Users/cfn18/Documents/PhD-Work/Third-Year/Instanton-Work/L96-EBM-Instanton-Cleaned-Up/L96-EBM-Effect-of-S/Attractor-Data//S_8_000/SB-State//1.nc. Erasing personal log.
#
# **Generating sb attractor data for S = 9.000.**
#
#
# ...
